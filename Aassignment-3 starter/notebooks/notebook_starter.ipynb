# %% [markdown]
# # Notebook starter
#
# Use this notebook to explore dataset1 and dataset2.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
d1 = pd.read_csv('dataset1.csv')
d1.head()
